# %% [markdown]
# **PREPARATION AND ANALYSIS OF SIESTA SIMULATIONS WITH PYTHON**
# --------------------------------------------------------------
#
# Using the pythin libray sisl, we can prepare simulations for SIESTA and analyze results.
# This notebook is based on the tutorials available here:
#
# https://sisl.readthedocs.io/en/latest/tutorials/index.html#siesta-transiesta-support

# %% [markdown]
# Setup
# -----
# We first import all required libraries

# %%
from sisl import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Visualization of a structure
# ----------------------------
# Example of loading and visualization of a fdf file with coordinates.

# %%
system = Geometry.read("/home/UAB/1667196/Desktop/Exemples siesta/C60/C60_coords.xyz") #llegeix el fitxer , pot ser un altre format .xyz

# %%
system.plot()#comanda de la llibreria sisl

# %%
system.plot(axes="xy") #aixo de q no estigui centrada es una putada, pq nsq en un altre programa, et tallara l estructura

# %% [markdown]
# ## Analysis of SIESTA Results
# **Load SIESTA Calculation**
#
# Once the SIESTA run has finished, to load SIESTA results into python you can use the following sisl command:
#
# ```python
# get_sile("path/to/my/file.fdf").read_hamiltonian()
# ```
#
# This will read the Hamiltonian with all the information of the system corresponding to this Hamiltonian.
# Lo q nos da es un hamiltoniano efectivo q representa el nou sistema. El q fem amb python es carregar aquest hamiltonian. Osea te da el potencial effectivo q te falta en el hamiltoniano.
# EN LINUX SI PONES ">"TE REDIRIGE TODO LO Q VERIAS EN OTRO LADO

# %%
fdf = get_sile("/home/UAB/1667196/Desktop/Exemples siesta/C60/C60_results/RUN.fdf")
print(fdf)
# Out:
# fdfSileSiesta(RUN.fdf, base=Desktop/Exemples siesta/C60/C60_results)

# %%
H = fdf.read_hamiltonian()

# %%
print(H)
# Out:
# Hamiltonian{non-zero: 418830, orthogonal: False,
#  Spin{unpolarized},
#  Geometry{na: 60, no: 780,
#   Atoms{species: 1,
#    Atom{C, Z: 6, mass(au): 12.01100, maxR: 3.30951,
#     AtomicOrbital{2sZ1, q0: 2.0, SphericalOrbital{l: 0, R: 2.6548991702149065, q0: 2.0}},
#     AtomicOrbital{2sZ2, q0: 0.0, SphericalOrbital{l: 0, R: 1.6858398488354462, q0: 0.0}},
#     AtomicOrbital{2pyZ1, q0: 0.6666666666666666, SphericalOrbital{l: 1, R: 3.309510260040147, q0: 2.0}},
#     AtomicOrbital{2pzZ1, q0: 0.6666666666666666, SphericalOrbital{l: 1, R: 3.309510260040147, q0: 2.0}},
#     AtomicOrbital{2pxZ1, q0: 0.6666666666666666, SphericalOrbital{l: 1, R: 3.309510260040147, q0: 2.0}},
#     AtomicOrbital{2pyZ2, q0: 0.0, SphericalOrbital{l: 1, R: 2.106206766003493, q0: 0.0}},
#     AtomicOrbital{2pzZ2, q0: 0.0, SphericalOrbital{l: 1, R: 2.106206766003493, q0: 0.0}},
#     AtomicOrbital{2pxZ2, q0: 0.0, SphericalOrbital{l: 1, R: 2.106206766003493, q0: 0.0}},
#     AtomicOrbital{3dxyZ1P, q0: 0.0, SphericalOrbital{l: 2, R: 3.309510260040147, q0: 0.0}},
#     AtomicOrbital{3dyzZ1P, q0: 0.0, SphericalOrbital{l: 2, R: 3.309510260040147, q0: 0.0}},
#     AtomicOrbital{3dz2Z1P, q0: 0.0, SphericalOrbital{l: 2, R: 3.309510260040147, q0: 0.0}},
#     AtomicOrbital{3dxzZ1P, q0: 0.0, SphericalOrbital{l: 2, R: 3.309510260040147, q0: 0.0}},
#     AtomicOrbital{3dx2-y2Z1P, q0: 0.0, SphericalOrbital{l: 2, R: 3.309510260040147, q0: 0.0}}
#    }: 60,
#   },
#   maxR: 3.30951,
#   Lattice{nsc: [1 1 1],
#    origin=[0.0000, 0.0000, 0.0000],
#    A=[16.0000, 0.0000, 0.0000],
#    B=[0.0000, 16.0000, 0.0000],
#    C=[0.0000, 0.0000, 16.0000],
#    bc=[Periodic,
#        Periodic,
#        Periodic]
#   }
#  }
# }

# %% [markdown]
# **Show Data employed in the calculation**
#
# Before analysing the diagonalisation of H, we can show the geometry of the system and the basis set employed

# %%
system = H.geometry

# %%
system.plot(axes="xy")

# %%
# FUNCTION PLOT ORBITALS
def plot_atom(atom):
    no = len(atom) # number of orbitals
    nx = no // 4
    ny = no // nx
    if nx * ny < no:
        nx += 1
    fig, axs = plt.subplots(nx, ny, figsize=(20, 5*nx))
    fig.suptitle('Atom: {}'.format(atom.symbol), fontsize=14)
    def my_plot(i, orb):
            grid = orb.toGrid(atom=atom)
            # Also write to a cube file
            grid.write('{}_{}.cube'.format(atom.symbol, orb.name()))
            c, r = i // 4, (i - 4) % 4
            if nx == 1:
                ax = axs[r]
            else:
                ax = axs[c][r]
            ax.imshow(grid.grid[:, :, grid.shape[2] // 2])
            ax.set_title(r'${}$'.format(orb.name(True)))
            ax.set_xlabel(r'$x$ [Ang]')
            ax.set_ylabel(r'$y$ [Ang]')
    i = 0
    for orb in atom:
            my_plot(i, orb)
            i += 1
    if i < nx * ny:
            # This removes the empty plots
            for j in range(i, nx * ny):
                c, r = j // 4, (j - 4) % 4
                if nx == 1:
                    ax = axs[r]
                else:
                    ax = axs[c][r]
                fig.delaxes(ax)
            plt.draw()

# %%
plot_atom(system.atoms[0]) #
plot_atom(system.atoms[1])
plt.show()

# %% [markdown]
# ## Eigenstates
#
# Once you have a hamiltonian, you can get all Eigenstates with `H.eigenstate()`. Then you can loop this object to get each individual eigenstate.
# - Each eigenstate has its energy stored under the `.eig` property.
# - We can find the HOMO and LUMO.
# - We can use the `.dos`  method to obtain the density of states DOS(E).
# - In sisl we can plot pdos directly in a given Energy range with something like `H.plot.pdos(data_Erange=[-10,10],nE=1200,Erange=[-10,10]) `

# %%
es=H.eigenstate()

# %%
es.eig  #l'energia esta en electronvolts, en siesta el 0 es el nivell de fermi
# Out:
# array([-17.01909909, -16.63281527, -16.62564271, -16.62383587,
#        -15.89340179, -15.88639517, -15.88068881, -15.8776722 ,
#        -15.8708432 , -15.19457864, -15.18868034, -15.17974138,
#        -14.24497093, -14.23341232, -14.22753644, -14.21083371,
#        -13.33928826, -13.32796037, -13.32324472, -13.31057918,
#        -13.30088033, -12.94195192, -12.93095136, -12.91706883,
#        -12.90552439, -11.9572821 , -11.95229564, -11.94467317,
#        -11.94138594, -11.9285915 , -11.45923804, -11.44003554,
#        -11.42514301, -10.13594004, -10.11780741, -10.09172207,
#         -9.9851326 ,  -9.97550938,  -9.97176637,  -9.4931778 ,
#         -9.49098625,  -9.48052183,  -9.460764  ,  -9.45491422,
#         -8.14407292,  -7.88806172,  -7.87934555,  -7.87315489,
#         -7.86185733,  -7.84645231,  -7.83830983,  -7.8248685 ,
#         56.32479234,  56.35756539,  56.37387972,  56.51735737,
#         56.5936763 ,  56.60572248,  56.64031769,  56.6654032 ,
#         56.71301566,  56.73007337,  56.74435105,  56.75229089,
#         56.84749358,  56.85377382,  56.91003563,  57.60102437,
#         57.60850134,  57.62032599,  57.63737105,  57.63915056,
#         58.27280391,  58.32423587,  58.34118299,  58.39034527,
#         58.41553539,  58.59123698,  58.59991621,  58.61687088,
#         60.51310084,  60.55336364,  60.57831253,  60.60178048,
#         60.63438194,  61.3380112 ,  61.35880695,  61.3859974 ,
#         61.41094431,  61.43174981,  61.43785498,  61.51215956,
#         62.04789914,  62.06398713,  62.08373188,  62.14007406,
#         63.26183304,  63.28201644,  63.29177129,  63.32829003,
#         63.34236998,  63.35143609,  63.38096933,  63.39564092,
#         63.43523825,  63.64280963,  63.69149686,  63.72235399,
#         63.72562743,  63.74724895,  64.34246493,  64.37382381,
#         64.40987838,  64.84274559,  64.93309672,  64.98072531,
#         65.87276739,  65.89326587,  65.91687843,  65.98753113,
#         67.83819621,  67.88433254,  67.96132428,  74.69118602,
#         74.73885124,  74.78659197,  74.85038869,  74.93336497,
#         75.43517214,  75.54264948,  75.55716478,  75.67892677,
#         76.59296105,  76.59992702,  76.64565835,  76.72082524,
#         76.92266654,  76.98238209,  77.00543211,  77.04513936,
#         77.08178405,  82.16259171,  82.17620263,  82.19718345,
#         82.23080073,  82.28001632,  82.29464274,  82.33077416,
#         83.92182234,  83.95064821,  83.95525903,  85.46850171,
#         86.97981252,  87.02625909,  87.08922436,  87.10409339,
#         87.17421485, 105.49846522, 105.57240883, 105.61685863,
#        105.66432109, 107.9572214 , 108.01020697, 108.02136109,
#        116.25282428, 116.34078756, 116.36571112, 117.27964494])

# %%
idx_lumo = (es.eig > 0).nonzero()[0][0] #trick to obtain the LUMO as first positive eigenvalue
idx_homo = idx_lumo-1

# %%
print(idx_lumo)
# Out:
# 120

# %%
print("HOMO E=",es.eig[idx_homo]," eV")
print("LUMO E=",es.eig[idx_lumo]," eV")
# Out:
# HOMO E= -0.5370867161013535  eV
# LUMO E= 0.5207515730176034  eV

# %% [markdown]
# -----------------------------------------------------------------------------------
# ## Exporting Wavefunctions for 3D plotting
#
# Create a grid and fill the grid with the probability density. The result can be sved in .cube format:
#
# https://paulbourke.net/dataformats/cube/
# #guardar dades en forma de boxels, son como pixels pero 3D.

# %% [markdown]
# **To compute wavefunctions on the grid:**
#
# To compute $\psi (\vec{r})$ you need three things.
#
# 1. **The eigenstate coefficients.** Once you have a hamiltonian, you can get all of them with `H.eigenstate()`. Then you can loop this object to get each individual eigenstate. Each eigenstate has its energy stored under the `.eig` property.
# 2. **A grid of points in space.** You can create one with `sisl.Grid(geometry, shape=(100, 100, 100))`. This will create a grid of $100x100x100$ points within the cell of your geometry.
# 3. **A function to project the wavefunction into the grid.** The eigenstate object has a `wavefunction` method ([docs](https://zerothi.github.io/sisl/api/generated/sisl.physics.electron.EigenstateElectron.html#sisl.physics.electron.EigenstateElectron.wavefunction)) that will project the wavefunction into an already initialized grid.
# 4. Once you have the wavefunction, you can calculate the electron density $\psi_i(\vec{r}) \psi_i^*(\vec{r})$.
# 5. The result can be saved in a '.cube' file and plotted with VMD
#
# This can always be done as in our first SIESTA lab, with a water molecule and with $C_{60}$.

# %%
import sys
# !{sys.executable} -m pip install nglview
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nglview in ./.local/lib/python3.13/site-packages (4.0.1)
# Requirement already satisfied: ipywidgets>=8 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nglview) (8.1.7)
# Requirement already satisfied: notebook>=7 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nglview) (7.5.0)
# Requirement already satisfied: jupyterlab>=3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nglview) (4.5.0)
# Requirement already satisfied: jupyterlab_widgets in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nglview) (3.0.15)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nglview) (2.3.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipywidgets>=8->nglview) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipywidgets>=8->nglview) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipywidgets>=8->nglview) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipywidgets>=8->nglview) (4.0.14)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=8->nglview) (0.8.5)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (6.31.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (3.1.6)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (0.2.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (72.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab>=3->nglview) (6.5.4)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (4.10.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=3->nglview) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab>=3->nglview) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (1.8.16)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (7.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab>=3->nglview) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.28.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-core->jupyterlab>=3->nglview) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.1.1)
# Requirement already satisfied: fqdn in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.5.1)
# Requirement already satisfied: isoduration in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.1.0)
# Requirement already satisfied: uri-template in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.local/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.5.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8->nglview) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in ./.local/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in ./.local/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.4.0)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2025.3)

# %%
system.lattice.origin = [-7, -7, -7] #culpa del danes, el cabezon. mueve la caja de la simulacion pa q qde centrada
g = Grid(0.2, lattice=system.lattice)  #defines a grid matching with our system

# %% [markdown]
# Save desired states (for example, HOMO and LUMO) in cube file

# %%
es[idx_homo].wavefunction(g)
g.write('HOMOC60def.cube')
print('Real space integrated wavefunction: {:.4f}'.format((np.absolute(g.grid) ** 2).sum() * g.dvolume))
g.fill(0) # reset the grid values to 0
# Out:
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
# Real space integrated wavefunction: 1.0000

# %%
es[idx_lumo].wavefunction(g)
g.write('LUMOC60def.cube')
print('Real space integrated wavefunction: {:.4f}'.format((np.absolute(g.grid) ** 2).sum() * g.dvolume))
g.fill(0) # reset the grid values to 0
# Out:
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
# Real space integrated wavefunction: 1.0000

# %% [markdown]
# Save Electron Density

# %%
g2 = Grid(0.2, lattice=system.lattice)

# %%
es[idx_lumo].wavefunction(g)
g2=g*g.grid.conj() 
g2.write('LUMOdensC60def.cube')
g2.fill(0) # reset the grid values to 0
#en tecnicas como STM, no miras solo un unico estado, sino una superposicion de estados
# Out:
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information

# %% [markdown]
# We can easily save the electron density including a range of states

# %%
Gt = Grid(0.2, lattice=system.lattice) 
for n in range(idx_lumo-4,idx_lumo):
    print("adding state",n)
    g.fill(0)
    es[n].wavefunction(g)
    Gt = Gt + g*g.grid.conj()
Gt.write('several_states.cube')
Gt.fill(0)
# Out:
# adding state 116
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
# adding state 117
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
# adding state 118
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
# adding state 119
# info:0: SislInfo:
#
# wavefunction: coordinates may be outside your primary unit-cell. Translating all into the primary unit cell could disable this information
